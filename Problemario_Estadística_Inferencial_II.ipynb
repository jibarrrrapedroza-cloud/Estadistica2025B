# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "examenes_cortos": [59, 92, 72, 90, 95, 87, 89, 77, 76, 65, 97, 42, 94, 62, 91],
    "promedio_final": [64, 84, 77, 80, 77, 81, 80, 84, 80, 69, 83, 40, 78, 65, 90]
})
#a) declarar variable dependiente e independiente

x=df["examenes_cortos"]
y=df["promedio_final"]



#b)diagrama de dispersión
import matplotlib.pyplot as plt
#figsize es la escala del cuadro
#dpi es la resolución del cuadro
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x , y, label="calificación", color="blue", s=30)
plt.xlabel("examenes_cortos", fontsize=20)
plt.ylabel("promedio_final", fontsize=20)
#plt.xlabel es para ponerle un titulo en la parte de la x o ylabel en la y
plt.title("grafico de dispersión",  fontsize=30, color="red")
##plt.title es para colocarle un titulo a toda la grafica
plt.gca().spines[["top","right"]]. set_visible(False)
##lo anterior es para quitar las lineas de arriba y la derecha para que se vea solo lo de x y y
plt.grid()
##plt.grid para cuadricular
plt.legend()
##plt.legend para colocar la leyenda de los puntos


##c) soporta la suposicion de linealidad
print("los datos soportan la suposición de linealidad")


##d) Calcule el coeficiente de correlación e interprete el resultado
# el coefiiente de correlacion parametro es P y estadistico r
# el coeficientcoeficiente de correlacion suele ser : -1<=r=<1
Sxx=((x-x.mean())**2).sum()
print("Sxx=",Sxx)
Syy=((y-y.mean())**2).sum()
print("Syy=",Syy)
Sxy=((x-x.mean())*(y-y.mean())).sum()
print("Sxy=",Sxy)
from math import sqrt
r=Sxy/sqrt(Sxx*Syy)
print("coeficiente de correlacion=",round(r,4))
##round(r, 4) sirve para limitar la cantidad de decimales que se requiere
print("coeficiente de correlacion (modo facil)",df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlacion (scipy)",pearsonr(x,y))

##e) Calcule el coeficiente de determinación e interprete el resultado
r2=r**2
print("coeficiente de determinación=",r2)
print("EL 75% de los examenes cortos predicen a la calificacion de los examenes finales")
##f) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión
from sklearn.metrics import r2_score
r=pearsonr(x,y)
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
print("parámetros:",modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x,yc)
#Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
##primero se establece el pecesito
print("\n")
intervalo_de_confianza=modelo.conf_int(alpha=0.05)
print("intervalo de confianza",intervalo_de_confianza)
#Calcule los residuales y trace un gráfico de dispersión. Comente,¿parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x,residuales,label="residuales",color="blue",s=30)
plt.xlabel("examenes_cortos",fontsize=20)
plt.ylabel("residuales", fontsize=20)
plt.title("Residuales",fontsize=30,color="red")
plt.gca().spines[["top","right"]].set_visible(False)
plt.grid()
plt.axhline(y=0, color= "grey",linestyle="--")
plt.axhline(y=0,color="gray",linestyle="--")
plt.show()
from scipy.stats import shapiro
estadistico_shapiro,valor_p_shapiro=shapiro(residuales)
print("valor-p(shapiro)=",valor_p_shapiro)
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("f(70)=",24.52+0.643*70)
print("x=70,",modelo.predict([1,70]))
from statsmodels.formula.api import ols
modelo_lineal=ols("promedio_final ~ examenes_cortos",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# los datos soportan la suposición de linealidad
# Sxx= 3718.3999999999996
# Syy= 2057.733333333333
# Sxy= 2391.6
# coeficiente de correlacion= 0.8646
# coeficiente de correlacion (modo facil)                  examenes_cortos  promedio_final
# examenes_cortos         1.000000        0.864601
# promedio_final          0.864601        1.000000
# coeficiente de correlacion (scipy) PearsonRResult(statistic=np.float64(0.8646014213752983), pvalue=np.float64(3.1971844162345565e-05))
# coeficiente de determinación= 0.7475356178441864
# EL 75% de los examenes cortos predicen a la calificacion de los examenes finales
# parámetros: const              24.526822
# examenes_cortos     0.643180
# dtype: float64
#
#
# intervalo de confianza                         0          1
# const            6.441997  42.611646
# examenes_cortos  0.419219   0.867141
# valor-p(shapiro)= 0.901827735700704
# valor_p de Breusch-Pagan:  0.2289
#
# f(70)= 69.53
# x=70, [69.54941193]
#                    df       sum_sq      mean_sq          F    PR(>F)
# examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual         13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# y=24.52+0.643x

# %% [markdown]
# inciso a)establecer una variable dependiente e independiente

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "salario": [11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8,3],
"ausencias": [18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31,40]
})
#A) declarar la variable
y=df["salario"]
x=df["ausencias"]
#b)diagrama de dispersión
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x , y, label="salario", color="blue", s=28)
plt.xlabel("salario", fontsize=20)
plt.ylabel("ausencias", fontsize=20)
plt.title("grafico de dispersión",  fontsize=30, color="red")
plt.gca().spines[["top","right"]]. set_visible(False)
plt.grid()
plt.legend()

##c) soporta la suposicion de linealidad
print("los datos soportan la suposición de linealidad")
#print("coeficiente de correlación(modo facil)"),df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlación (scipy)",pearsonr(x,y))
from sklearn.metrics import r2_score
r2=r2_score(x,y)
print("\n coeficiente de determinación=",round (r2,42))
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
modelo.params
print("parámetros:",modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x,yc, color="black", linestyle="--", linewidth=2, alpha=0.5)
plt.show()
#Calcule los residuales y trace un gráfico de dispersión. Comente,¿parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x,residuales,label="residuales",color="blue",s=30)
plt.xlabel("salario",fontsize=20)
plt.ylabel("ausencias", fontsize=20)
plt.title("Residuales",fontsize=30,color="red")
plt.gca().spines[["top","right"]].set_visible(False)
plt.grid()
plt.axhline(y=0, color= "grey",linestyle="--")
plt.axhline(y=0,color="gray",linestyle="--")
plt.show()
from scipy.stats import shapiro
estadistico_shapiro,valor_p_shapiro=shapiro(residuales)
print("valor-p(shapiro)=",valor_p_shapiro)
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
from statsmodels.formula.api import ols
modelo_lineal=ols("salario ~ ausencias",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
print("x=12",modelo.predict([1,12]))
print("x=70",modelo.predict([1,70]))
# Out:
# los datos soportan la suposición de linealidad
# coeficiente de correlación (scipy) PearsonRResult(statistic=np.float64(-0.8801262960169057), pvalue=np.float64(3.292893088695302e-05))
#
#  coeficiente de determinación= -4.562668766876687
# parámetros: const        14.058843
# ausencias    -0.261814
# dtype: float64
# valor-p(shapiro)= 0.4172971767713699
# valor_p de Breusch-Pagan:  0.8955
#
# x=12 [10.91707921]
# x=70 [-4.26811431]

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "gastos_generales": [191,170,272,155,280,173,234,116,153,178],
    "unidades": [40,42,53,35,56,39,48,30,37,40]
})
#a) declarar variable dependiente e independiente

x=df["gastos_generales"]
y=df["unidades"]



#b)diagrama de dispersión
import matplotlib.pyplot as plt
#figsize es la escala del cuadro
#dpi es la resolución del cuadro
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x , y, label="gastos_generales", color="blue", s=30)
plt.xlabel("unidades", fontsize=20)
plt.ylabel("gastos_generales", fontsize=20)
#plt.xlabel es para ponerle un titulo en la parte de la x o ylabel en la y
plt.title("grafico de dispersión",  fontsize=30, color="red")
##plt.title es para colocarle un titulo a toda la grafica
plt.gca().spines[["top","right"]]. set_visible(False)
##lo anterior es para quitar las lineas de arriba y la derecha para que se vea solo lo de x y y
plt.grid()
##plt.grid para cuadricular
plt.legend()
##plt.legend para colocar la leyenda de los puntos

#c) soporta la suposicion de linealidad
print("los datos soportan la suposición de linealidad")

#d) Calcule el coeficiente de correlación e interprete el resultado
# el coefiiente de correlacion parametro es P y estadistico r
# el coeficientcoeficiente de correlacion suele ser : -1<=r=<1
Sxx=((x-x.mean())**2).sum()
print("Sxx=",Sxx)
Syy=((y-y.mean())**2).sum()
print("Syy=",Syy)
Sxy=((x-x.mean())*(y-y.mean())).sum()
print("Sxy=",Sxy)
from math import sqrt
r=Sxy/sqrt(Sxx*Syy)
print("coeficiente de correlacion=",round(r,4))
##round(r, 4) sirve para limitar la cantidad de decimales que se requiere
#print("coeficiente de correlacion (modo facil)",df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlacion (scipy)",pearsonr(x,y))
#SE USARA ESTA PARA SACAR R

#f) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
modelo.params
print("parametros:",modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x,yc, color="black", linestyle="--", linewidth=2, alpha=0.5)
plt.show()
##quitamos el plt.show dde arriba para juntar las dos tablas, figure es el comienzo y hasta que no se coloque el show todo sera parte de la grafgrafica
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print("\n coeficiente de determinación=",round(r2,4))
#\n sirve para separar
#Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
##primero establecer el pecesito
print("\n")
intervalo_de_confianza= modelo.conf_int(alpha=0.05)
print("\n intervalo de confianza",intervalo_de_confianza)
#ff(5)=47.48-2.45(5)=35.23
#coeficiente de determinación= .7746 (la variacion el 77.46% de las veces x justifica a y, las ausencias el 77% de la variación en el salario se debe a las ausencia)
#Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x ,residuales, label="gastos_generales", color="blue", s=30)
plt.xlabel("unidades", fontsize=20)
plt.ylabel("residuales", fontsize=20)
plt.title("Residuales",  fontsize=30, color="red")
plt.gca().spines[["top","right"]]. set_visible(False)
plt.grid()
plt.axhline(y=0, color="grey", linestyle="--")
plt.show()
from scipy.stats import shapiro
estadictico_shapiro, valor_p_shapiro=shapiro(residuales)
print("valores_p(shapir)=",valor_p_shapiro)
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
modelo.params
#f(x)=24.52+.64x
#f(70)=24.52+.64(70)=69.53
print("x=12,",modelo.predict([1,12]))
print("x=30,",modelo.predict([1,30]))
print("x=70,",modelo.predict([1,70]))
from statsmodels.formula.api import ols
modelo_lineal = ols("gastos_generales~unidades", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
print(tabla_anova)

#ho b1=0x por lo que hay correlación, checra foto ddel 10 de septiempre 1:49
# Out:
# los datos soportan la suposición de linealidad
# Sxx= 25615.6
# Syy= 588.0
# Sxy= 3817.0
# coeficiente de correlacion= 0.9835
# coeficiente de correlacion (scipy) PearsonRResult(statistic=np.float64(0.9835155492696092), pvalue=np.float64(3.1670797383293894e-07))
# parametros: const               13.360132
# gastos_generales     0.149011
# dtype: float64
#  coeficiente de determinación= 0.9673
#
#
#
#  intervalo de confianza                          0          1
# const             8.920794  17.799471
# gastos_generales  0.126675   0.171347
# valores_p(shapir)= 0.30963893537419923
# valor_p de Breusch-Pagan:  0.6267
#
# x=12, [15.14826122]
# x=30, [17.83045488]
# x=70, [23.79088524]
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "linea_blanca": [5,5.5,6,7,7.2,7.7,8.4,9,9.7,10],
    "casa": [2,2.5,3.2,3.6,3.7,4,4.2,4.6,4.8,5]
})
#a) declarar variable dependiente e independiente

x=df["casa"]
y=df["linea_blanca"]



#b)diagrama de dispersión
import matplotlib.pyplot as plt
#figsize es la escala del cuadro
#dpi es la resolución del cuadro
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x , y, label="linea_blanca", color="blue", s=30)
plt.xlabel("casa", fontsize=20)
plt.ylabel("linea_blanca", fontsize=20)
#plt.xlabel es para ponerle un titulo en la parte de la x o ylabel en la y
plt.title("grafico de dispersión",  fontsize=30, color="red")
##plt.title es para colocarle un titulo a toda la grafica
plt.gca().spines[["top","right"]]. set_visible(False)
##lo anterior es para quitar las lineas de arriba y la derecha para que se vea solo lo de x y y
plt.grid()
##plt.grid para cuadricular
plt.legend()
##plt.legend para colocar la leyenda de los puntos

#c) soporta la suposicion de linealidad
print("los datos soportan la suposición de linealidad")

#d) Calcule el coeficiente de correlación e interprete el resultado
# el coefiiente de correlacion parametro es P y estadistico r
# el coeficientcoeficiente de correlacion suele ser : -1<=r=<1
Sxx=((x-x.mean())**2).sum()
print("Sxx=",Sxx)
Syy=((y-y.mean())**2).sum()
print("Syy=",Syy)
Sxy=((x-x.mean())*(y-y.mean())).sum()
print("Sxy=",Sxy)
from math import sqrt
r=Sxy/sqrt(Sxx*Syy)
print("coeficiente de correlacion=",round(r,4))
##round(r, 4) sirve para limitar la cantidad de decimales que se requiere
#print("coeficiente de correlacion (modo facil)",df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlacion (scipy)",pearsonr(x,y))
#SE USARA ESTA PARA SACAR R

#f) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
modelo.params
print("parametros:",modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x,yc, color="black", linestyle="--", linewidth=2, alpha=0.5)
plt.show()
##quitamos el plt.show dde arriba para juntar las dos tablas, figure es el comienzo y hasta que no se coloque el show todo sera parte de la grafgrafica
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print("\n coeficiente de determinación=",round(r2,4))
#\n sirve para separar
#Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
##primero establecer el pecesito
print("\n")
intervalo_de_confianza= modelo.conf_int(alpha=0.05)
print("\n intervalo de confianza",intervalo_de_confianza)
#ff(5)=47.48-2.45(5)=35.23
#coeficiente de determinación= .7746 (la variacion el 77.46% de las veces x justifica a y, las ausencias el 77% de la variación en el salario se debe a las ausencia)
#Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x ,residuales, label="residuales", color="blue", s=30)
plt.xlabel("linea_blanca", fontsize=20)
plt.ylabel("residuales", fontsize=20)
plt.title("Residuales",  fontsize=30, color="red")
plt.gca().spines[["top","right"]]. set_visible(False)
plt.grid()
plt.axhline(y=0, color="grey", linestyle="--")
plt.show()
from scipy.stats import shapiro
estadictico_shapiro, valor_p_shapiro=shapiro(residuales)
print("valores_p(shapir)=",valor_p_shapiro)
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
modelo.params
#f(x)=24.52+.64x
#f(70)=24.52+.64(70)=69.53
print("x=12,",modelo.predict([1,12]))
print("x=30,",modelo.predict([1,30]))
print("x=70,",modelo.predict([1,70]))
from statsmodels.formula.api import ols
modelo_lineal = ols("casa~linea_blanca", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
print(tabla_anova)

#ho b1=0x por lo que hay correlación, checra foto ddel 10 de septiempre 1:49
# Out:
# los datos soportan la suposición de linealidad
# Sxx= 8.604
# Syy= 27.005
# Sxy= 14.95
# coeficiente de correlacion= 0.9808
# coeficiente de correlacion (scipy) PearsonRResult(statistic=np.float64(0.9807739021534332), pvalue=np.float64(5.841003144127694e-07))
# parametros: const    1.016760
# casa     1.737564
# dtype: float64
#  coeficiente de determinación= 0.9619
#
#
#
#  intervalo de confianza               0         1
# const -0.074848  2.108368
# casa   1.455693  2.019435
# valores_p(shapir)= 0.8463507249054649
# valor_p de Breusch-Pagan:  0.1581
#
# x=12, [21.86752673]
# x=30, [53.14367736]
# x=70, [122.64623431]
#                df    sum_sq   mean_sq           F        PR(>F)
# linea_blanca  1.0  8.276338  8.276338  202.069951  5.841003e-07
# Residual      8.0  0.327662  0.040958         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "calificación": [58,41,45,27,26,12,16,3],
    "interrupciones": [5,10,10,15,15,20,20,25]
})
#a) declarar variable dependiente e independiente

x=df["interrupciones"]
y=df["calificación"]



#b)diagrama de dispersión
import matplotlib.pyplot as plt
#figsize es la escala del cuadro
#dpi es la resolución del cuadro
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x , y, label="calificación", color="blue", s=30)
plt.xlabel("interrupciones", fontsize=20)
plt.ylabel("calificación", fontsize=20)
#plt.xlabel es para ponerle un titulo en la parte de la x o ylabel en la y
plt.title("grafico de dispersión",  fontsize=30, color="red")
##plt.title es para colocarle un titulo a toda la grafica
plt.gca().spines[["top","right"]]. set_visible(False)
##lo anterior es para quitar las lineas de arriba y la derecha para que se vea solo lo de x y y
plt.grid()
##plt.grid para cuadricular
plt.legend()
##plt.legend para colocar la leyenda de los puntos

#c) soporta la suposicion de linealidad
print("los datos soportan la suposición de linealidad")

#d) Calcule el coeficiente de correlación e interprete el resultado
# el coefiiente de correlacion parametro es P y estadistico r
# el coeficientcoeficiente de correlacion suele ser : -1<=r=<1
Sxx=((x-x.mean())**2).sum()
print("Sxx=",Sxx)
Syy=((y-y.mean())**2).sum()
print("Syy=",Syy)
Sxy=((x-x.mean())*(y-y.mean())).sum()
print("Sxy=",Sxy)
from math import sqrt
r=Sxy/sqrt(Sxx*Syy)
print("coeficiente de correlacion=",round(r,4))
##round(r, 4) sirve para limitar la cantidad de decimales que se requiere
#print("coeficiente de correlacion (modo facil)",df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlacion (scipy)",pearsonr(x,y))
#SE USARA ESTA PARA SACAR R

#f) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
modelo.params
print("parametros:",modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x,yc, color="black", linestyle="--", linewidth=2, alpha=0.5)
plt.show()
##quitamos el plt.show dde arriba para juntar las dos tablas, figure es el comienzo y hasta que no se coloque el show todo sera parte de la grafgrafica
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print("\n coeficiente de determinación=",round(r2,4))
#\n sirve para separar
#Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
##primero establecer el pecesito
print("\n")
intervalo_de_confianza= modelo.conf_int(alpha=0.05)
print("\n intervalo de confianza",intervalo_de_confianza)
#ff(5)=47.48-2.45(5)=35.23
#coeficiente de determinación= .7746 (la variacion el 77.46% de las veces x justifica a y, las ausencias el 77% de la variación en el salario se debe a las ausencia)
#Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(figsize=(10,7),dpi=100)
plt.scatter(x ,residuales, label="residuales", color="blue", s=30)
plt.xlabel("calificación", fontsize=20)
plt.ylabel("residuales", fontsize=20)
plt.title("Residuales",  fontsize=30, color="red")
plt.gca().spines[["top","right"]]. set_visible(False)
plt.grid()
plt.axhline(y=0, color="grey", linestyle="--")
plt.show()
from scipy.stats import shapiro
estadictico_shapiro, valor_p_shapiro=shapiro(residuales)
print("valores_p(shapir)=",valor_p_shapiro)
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
modelo.params
#f(x)=24.52+.64x
#f(70)=24.52+.64(70)=69.53
print("x=12,",modelo.predict([1,12]))
print("x=30,",modelo.predict([1,30]))
print("x=70,",modelo.predict([1,70]))
from statsmodels.formula.api import ols
modelo_lineal = ols("interrupciones~calificación", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
print(tabla_anova)

#ho b1=0x por lo que hay correlación, checra foto ddel 10 de septiempre 1:49
# Out:
# los datos soportan la suposición de linealidad
# Sxx= 300.0
# Syy= 2386.0
# Sxy= -840.0
# coeficiente de correlacion= -0.9928
# coeficiente de correlacion (scipy) PearsonRResult(statistic=np.float64(-0.9928495402404849), pvalue=np.float64(9.090963971926991e-07))
# parametros: const             70.5
# interrupciones    -2.8
# dtype: float64
#  coeficiente de determinación= 0.9858
#
#
#
#  intervalo de confianza                         0          1
# const           65.051384  75.948616
# interrupciones  -3.136296  -2.463704
# valores_p(shapir)= 0.054816491127669634
# valor_p de Breusch-Pagan:  0.2482
#
# x=12, [36.9]
# x=30, [-13.5]
# x=70, [-125.5]
#                df      sum_sq     mean_sq           F        PR(>F)
# calificación  1.0  295.725063  295.725063  415.058824  9.090964e-07
# Residual      6.0    4.274937    0.712490         NaN           NaN
